# %%
import pandas as pd
import sys
sys.path.append("src")

from analyse_wb_senegal.api import get_export
from analyse_wb_senegal.api import get_import
from analyse_wb_senegal.api import get_pib




dataframe_exportations=get_export("SN", "2000", "2023")
pd.set_option('display.float_format', '{:,.0f}'.format)
print(dataframe_exportations)


print("\n --- \n ")
dataframe_importations=get_import("SN", "2000", "2023")
pd.set_option('display.float_format', '{:,.0f}'.format)
print(dataframe_importations)


print("\n --- \n ")
dataframe_pib=get_pib("SN", "2000", "2023")
pd.set_option('display.float_format', '{:,.0f}'.format)
print(dataframe_pib)
# Out:
# Donnée première ligne : {'indicator': {'id': 'NE.EXP.GNFS.CD', 'value': 'Exports of goods and services (current US$)'}, 'country': {'id': 'SN', 'value': 'Senegal'}, 'countryiso3code': 'SEN', 'date': '2023', 'value': 7092859222.86761, 'unit': '', 'obs_status': '', 'decimal': 0}
#        pays annee  exportations_usd
# 0   Senegal  2023     7,092,859,223
# 1   Senegal  2022     7,417,917,497
# 2   Senegal  2021     6,781,011,709
# 3   Senegal  2020     5,077,951,817
# 4   Senegal  2019     5,847,051,726
# 5   Senegal  2018     5,305,072,987
# 6   Senegal  2017     4,604,563,712
# 7   Senegal  2016     4,105,254,723
# 8   Senegal  2015     4,030,818,416
# 9   Senegal  2014     4,311,504,601
# 10  Senegal  2013     4,228,273,485
# 11  Senegal  2012     3,969,170,142
# 12  Senegal  2011     3,795,074,624
# 13  Senegal  2010     3,221,238,634
# 14  Senegal  2009     3,131,307,996
# 15  Senegal  2008     3,513,433,452
# 16  Senegal  2007     2,876,425,982
# ...
